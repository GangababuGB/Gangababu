# %%
# pip install easyocr

# %%
# !wget https://i.pinimg.com/originals/04/d9/0c/04d90c48caa3be6cc7a03a9064019964.png
# Out:
# --2022-02-17 13:03:53--  https://i.pinimg.com/originals/04/d9/0c/04d90c48caa3be6cc7a03a9064019964.png
# Resolving i.pinimg.com (i.pinimg.com)... 199.232.4.84, 2a04:4e42:5f::84
# Connecting to i.pinimg.com (i.pinimg.com)|199.232.4.84|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18518 (18K) [image/png]
# Saving to: ‘04d90c48caa3be6cc7a03a9064019964.png’
#
# 04d90c48caa3be6cc7a 100%[===================>]  18.08K  --.-KB/s    in 0s
#
# 2022-02-17 13:03:53 (52.1 MB/s) - ‘04d90c48caa3be6cc7a03a9064019964.png’ saved [18518/18518]

# %%
file_n = '04d90c48caa3be6cc7a03a9064019964.png'

# %%
import PIL

# %%
from PIL import ImageDraw
im = PIL.Image.open(file_n)

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=437x709 at 0x7F0C2FC73A10>

# %%
# pip install opencv-python-headless==4.5.2.52

# %%
import easyocr
reader = easyocr.Reader(['en'])

# %%
bounds = reader.readtext(file_n)
bounds
# Out:
# [([[132, 22], [308, 22], [308, 46], [132, 46]],
#   'INCOME STATEMENT',
#   0.9988977310650456),
#  ([[119, 47], [157, 47], [157, 59], [119, 59]], 'For the', 0.926344470553764),
#  ([[165, 45], [323, 45], [323, 61], [165, 61]],
#   'ears Ending December 31, 2017',
#   0.6258363727942008),
#  ([[59, 77], [127, 77], [127, 91], [59, 91]], 'REVENUES:', 0.8099199560856529),
#  ([[59, 93], [147, 93], [147, 107], [59, 107]],
#   'Sales Revenue',
#   0.8752889748062427),
#  ([[287, 93], [343, 93], [343, 107], [287, 107]],
#   'S500,000',
#   0.7929533557519266),
#  ([[59, 109], [145, 109], [145, 123], [59, 123]],
#   'Other Revenue',
#   0.999395551862007),
#  ([[59, 125], [177, 125], [177, 139], [59, 139]],
#   '(Less Sales Returns',
#   0.8043718989589183),
#  ([[187, 125], [253, 125], [253, 139], [187, 139]],
#   'Allowances',
#   0.9999180064465684),
#  ([[59, 141], [165, 141], [165, 155], [59, 155]],
#   'TOTAL REVENUES',
#   0.7860912999156848),
# ...

# %%
def draw_boxes(image, bounds, color='yellow', width=2 ):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image
draw_boxes(im, bounds)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=437x709 at 0x7F0C2FC73A10>

# %%
bounds = reader.readtext(file_n,contrast_ths=0.05,adjust_contrast=0.7,add_margin=0.45,width_ths=0.7,decoder='beamsearch')
bounds
# Out:
# [([[125, 15], [315, 15], [315, 53], [125, 53]],
#   'INCOME STATEMENT ',
#   0.32406114590672414),
#  ([[116, 44], [160, 44], [160, 62], [116, 62]], 'For the`', 0.702975972230671),
#  ([[160, 40], [328, 40], [328, 66], [160, 66]],
#   'Years Ending December 31,2017',
#   0.9142919982511263),
#  ([[55, 73], [131, 73], [131, 95], [55, 95]], 'REVENUES:', 0.9997244486124046),
#  ([[55, 89], [151, 89], [151, 111], [55, 111]],
#   'Sales Revenue',
#   0.9957343498290011),
#  ([[283, 89], [347, 89], [347, 111], [283, 111]],
#   'ss00,0o0',
#   0.1649048442145676),
#  ([[55, 105], [149, 105], [149, 127], [55, 127]],
#   'Other Revenue',
#   0.9995694491308577),
#  ([[321, 105], [347, 105], [347, 127], [321, 127]], 's0', 0.2890348874849055),
#  ([[55, 121], [181, 121], [181, 143], [55, 143]],
#   '(Less Sales Returns E',
#   0.8008336724961724),
#  ([[183, 121], [257, 121], [257, 143], [183, 143]],
#   'Alowances',
#   0.955865468511674),
#  ([[55, 137], [169, 137], [169, 159], [55, 159]],
# ...

# %%
bounds[0]
# Out:
# ([[125, 15], [315, 15], [315, 53], [125, 53]],
#  'INCOME STATEMENT ',
#  0.32406114590672414)

# %%
bounds[0][1]
# Out:
# 'INCOME STATEMENT '

# %%
def draw_boxes(image, bounds, color='yellow', width=2 ):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image
draw_boxes(im, bounds)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=437x709 at 0x7F0C2FC73A10>
